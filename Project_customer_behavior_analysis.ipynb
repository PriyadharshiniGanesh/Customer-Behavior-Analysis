# %%
import pandas as pd
import numpy as np

# %%
journey_df = pd.read_csv('customer_journey.csv')
journey_df
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate        Stage    Action  \
# 0           1          64         18  2024-06-10     Checkout  Drop-off
# 1           2          94         11  2025-07-09     Checkout  Drop-off
# 2           3          34          8  2024-06-14  ProductPage      View
# 3           4          33         18  2025-05-28     Checkout  Drop-off
# 4           5          91         10  2023-02-11     Homepage     Click
# ..        ...         ...        ...         ...          ...       ...
# 95         96          22          9  2024-07-28  ProductPage      View
# 96         97          92         19  2025-05-26     homepage      View
# 97         98          95          8  2025-05-25     Homepage     Click
# 98         99          58         16  2024-07-06     Checkout  Purchase
# 99        100          92         10  2024-04-06  ProductPage      View
#
#     Duration
# 0        NaN
# 1        NaN
# 2      235.0
# 3        NaN
# 4      156.0
# ..       ...
# 95     212.0
# 96     203.0
# 97      68.0
# 98      87.0
# 99     237.0
#
# [100 rows x 7 columns]

# %%
print(journey_df.isnull().sum())
# Out:
# JourneyID      0
# CustomerID     0
# ProductID      0
# VisitDate      0
# Stage          0
# Action         0
# Duration      14
# dtype: int64

# %%
journey_df1 = journey_df.fillna(journey_df.mean(numeric_only = True))
journey_df1
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate        Stage    Action  \
# 0           1          64         18  2024-06-10     Checkout  Drop-off
# 1           2          94         11  2025-07-09     Checkout  Drop-off
# 2           3          34          8  2024-06-14  ProductPage      View
# 3           4          33         18  2025-05-28     Checkout  Drop-off
# 4           5          91         10  2023-02-11     Homepage     Click
# ..        ...         ...        ...         ...          ...       ...
# 95         96          22          9  2024-07-28  ProductPage      View
# 96         97          92         19  2025-05-26     homepage      View
# 97         98          95          8  2025-05-25     Homepage     Click
# 98         99          58         16  2024-07-06     Checkout  Purchase
# 99        100          92         10  2024-04-06  ProductPage      View
#
#       Duration
# 0   166.534884
# 1   166.534884
# 2   235.000000
# 3   166.534884
# 4   156.000000
# ..         ...
# 95  212.000000
# 96  203.000000
# 97   68.000000
# 98   87.000000
# 99  237.000000
#
# [100 rows x 7 columns]

# %%
review_df = pd.read_csv('customer_reviews.csv')
review_df
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2023-12-23       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# ..       ...         ...        ...         ...     ...
# 95        96          19         13  2023-09-02       3
# 96        97          64          6  2024-01-19       3
# 97        98          96          3  2025-11-20       5
# 98        99          79         16  2025-01-29       2
# 99       100           9          2  2025-06-20       3
#
#                                            ReviewText
# 0             Average  experience,  nothing  special.
# 1                      The  quality  is    top-notch.
# 2             Five  stars  for  the  quick  delivery.
# 3            Good  quality,  but  could  be  cheaper.
# 4             Average  experience,  nothing  special.
# ..                                                ...
# 95           Good  quality,  but  could  be  cheaper.
# 96  The  product  is  okay,  but  the  instruction...
# 97                        Exceeded  my  expectations!
# 98            Average  experience,  nothing  special.
# 99                            Not  worth  the  money.
#
# [100 rows x 6 columns]

# %%
customers_df = pd.read_csv('customers.csv')
customers_df
# Out:
#     CustomerID      CustomerName                         Email  Gender  Age  \
# 0            1     Emma Anderson     emma.anderson@example.com    Male   50
# 1            2       Sarah Brown       sarah.brown@example.com  Female   37
# 2            3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3            4      David Garcia      david.garcia@example.com    Male   25
# 4            5       Emma Miller       emma.miller@example.com  Female   41
# ..         ...               ...                           ...     ...  ...
# 95          96    Emily Gonzalez    emily.gonzalez@example.com  Female   38
# 96          97   Emily Rodriguez   emily.rodriguez@example.com  Female   51
# 97          98       Chris Lopez       chris.lopez@example.com  Female   55
# 98          99   Laura Hernandez   laura.hernandez@example.com    Male   41
# 99         100        Jane Brown        jane.brown@example.com  Female   45
#
#     GeographyID
# 0             2
# 1             4
# 2             6
# 3             8
# 4             4
# ..          ...
# 95           10
# 96            3
# 97           10
# 98            5
# 99           10
#
# [100 rows x 6 columns]

# %%
engagement_df = pd.read_csv('engagement_data.csv')
engagement_df
# Out:
#     EngagementID  ContentID ContentType  Likes EngagementDate  CampaignID  \
# 0              1         39        Blog    190     2023-08-30           1
# 1              2         48        Blog    114     2023-03-28          18
# 2              3         16       video     32     2023-12-08           7
# 3              4         43       Video     17     2025-01-21          19
# 4              5         16  newsletter    306     2024-02-21           6
# ..           ...        ...         ...    ...            ...         ...
# 95            96         17        Blog     32     2024-07-15          14
# 96            97         34        blog      3     2025-07-01          16
# 97            98         44        blog      0     2025-08-20          11
# 98            99         26        Blog    119     2024-04-15          17
# 99           100         32       Video     34     2024-05-05          15
#
#     ProductID ViewsClicksCombined
# 0           9            1883-671
# 1          20            5280-532
# 2          14            1905-204
# 3          20            2766-257
# 4          15           5116-1524
# ..        ...                 ...
# 95         13             712-142
# 96          7              696-47
# 97          8              231-10
# 98          4            3511-479
# 99         13            2657-175
#
# [100 rows x 8 columns]

# %%
geography_df = pd.read_csv('geography.csv')
geography_df
# Out:
#    GeographyID      Country       City
# 0            1           UK     London
# 1            2      Germany     Berlin
# 2            3       France      Paris
# 3            4        Spain     Madrid
# 4            5        Italy       Rome
# 5            6  Netherlands  Amsterdam
# 6            7      Belgium   Brussels
# 7            8       Sweden  Stockholm
# 8            9  Switzerland     Zurich
# 9           10      Austria     Vienna

# %%
product_df = pd.read_csv('products.csv')
product_df
# Out:
#     ProductID      ProductName Category   Price
# 0           1    Running Shoes   Sports  223.75
# 1           2  Fitness Tracker   Sports  196.68
# 2           3         Yoga Mat   Sports  485.32
# 3           4        Dumbbells   Sports   26.21
# 4           5      Soccer Ball   Sports   41.26
# 5           6    Tennis Racket   Sports   36.07
# 6           7       Basketball   Sports  225.12
# 7           8  Football Helmet   Sports   44.75
# 8           9   Baseball Glove   Sports  327.36
# 9          10       Golf Clubs   Sports   81.59
# 10         11        Ski Boots   Sports  340.20
# 11         12       Ice Skates   Sports   37.56
# 12         13     Swim Goggles   Sports  145.97
# 13         14   Cycling Helmet   Sports  472.32
# 14         15    Climbing Rope   Sports  410.17
# 15         16            Kayak   Sports  259.40
# 16         17        Surfboard   Sports  275.43
# 17         18       Volleyball   Sports   42.80
# 18         19     Hockey Stick   Sports  173.83
# 19         20    Boxing Gloves   Sports  262.32

# %%
from mysql.connector import connect

# %%
## Establishing connection with database
# connect is clause
connection = connect(
    host = "localhost",
    user = "root",
    password = "Ganeshpriya5@"
)
cursor_mysql =  connection.cursor()

print("MySQL connection established")
# Out:
# MySQL connection established

# %%
cursor_mysql.execute("CREATE DATABASE IF NOT EXISTS customer_behavior_df;")
print("MySQL database 'customer_behavior_df' created successfully")
# Out:
# MySQL database 'customer_behavior_df' created successfully

# %%
# Best performing product per region
cust_geo= pd.merge(geography_df, customers_df, on = "GeographyID")
cust_geo
# Out:
#     GeographyID  Country    City  CustomerID     CustomerName  \
# 0             1       UK  London          13     David Wilson
# 1             1       UK  London          20    David Johnson
# 2             1       UK  London          26  Isabella Thomas
# 3             1       UK  London          27   John Rodriguez
# 4             1       UK  London          42    John Gonzalez
# ..          ...      ...     ...         ...              ...
# 95           10  Austria  Vienna          76    Michael Lopez
# 96           10  Austria  Vienna          86  James Hernandez
# 97           10  Austria  Vienna          96   Emily Gonzalez
# 98           10  Austria  Vienna          98      Chris Lopez
# 99           10  Austria  Vienna         100       Jane Brown
#
#                           Email  Gender  Age
# 0      david.wilson@example.com    Male   50
# 1     david.johnson@example.com    Male   22
# 2   isabella.thomas@example.com    Male   31
# 3    john.rodriguez@example.com    Male   23
# 4     john.gonzalez@example.com  Female   69
# ..                          ...     ...  ...
# 95    michael.lopez@example.com  Female   26
# 96  james.hernandez@example.com    Male   63
# 97   emily.gonzalez@example.com  Female   38
# 98      chris.lopez@example.com  Female   55
# 99       jane.brown@example.com  Female   45
#
# [100 rows x 8 columns]

# %%
cust_geo_journey = pd.merge(cust_geo, journey_df1, on = "CustomerID")
cust_geo_journey
# Out:
#     GeographyID  Country    City  CustomerID     CustomerName  \
# 0             1       UK  London          13     David Wilson
# 1             1       UK  London          20    David Johnson
# 2             1       UK  London          42    John Gonzalez
# 3             1       UK  London          42    John Gonzalez
# 4             1       UK  London          55      Emily Lopez
# ..          ...      ...     ...         ...              ...
# 95           10  Austria  Vienna          51    Michael Davis
# 96           10  Austria  Vienna          58    Jane Williams
# 97           10  Austria  Vienna          58    Jane Williams
# 98           10  Austria  Vienna          58    Jane Williams
# 99           10  Austria  Vienna          86  James Hernandez
#
#                           Email  Gender  Age  JourneyID  ProductID  \
# 0      david.wilson@example.com    Male   50         38         18
# 1     david.johnson@example.com    Male   22         73         16
# 2     john.gonzalez@example.com  Female   69         62          1
# 3     john.gonzalez@example.com  Female   69         76         17
# 4       emily.lopez@example.com  Female   60         34         15
# ..                          ...     ...  ...        ...        ...
# 95    michael.davis@example.com  Female   63         63         15
# 96    jane.williams@example.com    Male   34         21         20
# 97    jane.williams@example.com    Male   34         23          1
# 98    jane.williams@example.com    Male   34         99         16
# 99  james.hernandez@example.com    Male   63         64         20
#
#      VisitDate        Stage    Action    Duration
# 0   2023-02-23  ProductPage      View  227.000000
# 1   2024-09-17     Homepage      View   17.000000
# 2   2024-10-22     Homepage      View  186.000000
# 3   2025-05-29     Checkout  Purchase  261.000000
# 4   2023-10-26     Homepage      View  233.000000
# ..         ...          ...       ...         ...
# 95  2025-05-22     Homepage      View  139.000000
# 96  2024-03-07     Checkout  Drop-off  166.534884
# 97  2023-07-05     Homepage      View   48.000000
# 98  2024-07-06     Checkout  Purchase   87.000000
# 99  2023-07-03  ProductPage      View   77.000000
#
# [100 rows x 14 columns]

# %%
successfull_purchase = cust_geo_journey[cust_geo_journey["Action"] != "Drop-off"]
product_performance = (
    successfull_purchase.groupby(["Country", "City","ProductID"])
    .size()
    .reset_index(name = "PurchaseCount")
)
product_performance
# Out:
#     Country    City  ProductID  PurchaseCount
# 0   Austria  Vienna          1              3
# 1   Austria  Vienna          4              1
# 2   Austria  Vienna         15              1
# 3   Austria  Vienna         16              1
# 4   Austria  Vienna         20              2
# ..      ...     ...        ...            ...
# 64       UK  London         15              1
# 65       UK  London         16              1
# 66       UK  London         17              1
# 67       UK  London         18              1
# 68       UK  London         19              2
#
# [69 rows x 4 columns]

# %%
best_products = product_performance.loc[
    product_performance.groupby(["Country", "City"])["PurchaseCount"].idxmax()
]
best_products
# Out:
#         Country       City  ProductID  PurchaseCount
# 0       Austria     Vienna          1              3
# 6       Belgium   Brussels          2              2
# 11       France      Paris          4              1
# 17      Germany     Berlin          2              1
# 26        Italy       Rome         10              3
# 34  Netherlands  Amsterdam         15              2
# 40        Spain     Madrid          8              3
# 48       Sweden  Stockholm         12              1
# 58  Switzerland     Zurich         18              3
# 68           UK     London         19              2

# %%
best_products_region =  pd.DataFrame(best_products, columns  = ['Country', 'City', 'ProductID', 'PurchaseCount'])
print(best_products_region)
# Out:
#         Country       City  ProductID  PurchaseCount
# 0       Austria     Vienna          1              3
# 6       Belgium   Brussels          2              2
# 11       France      Paris          4              1
# 17      Germany     Berlin          2              1
# 26        Italy       Rome         10              3
# 34  Netherlands  Amsterdam         15              2
# 40        Spain     Madrid          8              3
# 48       Sweden  Stockholm         12              1
# 58  Switzerland     Zurich         18              3
# 68           UK     London         19              2

# %%
# review trend with product performance

# sentiment analysis
complaints = review_df.groupby(["ProductID","ReviewText"])["Rating"].mean().reset_index().sort_values(by='Rating', ascending=False)
key_complaints = complaints.tail(10)
key_complaints
# Out:
#     ProductID                                         ReviewText  Rating
# 53         13            Average  experience,  nothing  special.     3.0
# 72         17            Average  experience,  nothing  special.     2.5
# 66         16            Average  experience,  nothing  special.     2.0
# 41         10              Disappointed  with  the  performance.     2.0
# 8           2       Product  did    not  meet  my  expectations.     2.0
# 31          7  The  product    is  okay,  but  the  instructi...     2.0
# 65         15                     The  product  arrived    late.     2.0
# 13          3                            Not  worth  the  money.     1.0
# 20          4   The  product  stopped  working  after  a  month.     1.0
# 27          6   I  had  a  bad  experience  with  this  product.     1.0

# %%
com_product = pd.merge(key_complaints, product_df, on = "ProductID")
com_product
# Out:
#    ProductID                                         ReviewText  Rating  \
# 0         13            Average  experience,  nothing  special.     3.0
# 1         17            Average  experience,  nothing  special.     2.5
# 2         16            Average  experience,  nothing  special.     2.0
# 3         10              Disappointed  with  the  performance.     2.0
# 4          2       Product  did    not  meet  my  expectations.     2.0
# 5          7  The  product    is  okay,  but  the  instructi...     2.0
# 6         15                     The  product  arrived    late.     2.0
# 7          3                            Not  worth  the  money.     1.0
# 8          4   The  product  stopped  working  after  a  month.     1.0
# 9          6   I  had  a  bad  experience  with  this  product.     1.0
#
#        ProductName Category   Price
# 0     Swim Goggles   Sports  145.97
# 1        Surfboard   Sports  275.43
# 2            Kayak   Sports  259.40
# 3       Golf Clubs   Sports   81.59
# 4  Fitness Tracker   Sports  196.68
# 5       Basketball   Sports  225.12
# 6    Climbing Rope   Sports  410.17
# 7         Yoga Mat   Sports  485.32
# 8        Dumbbells   Sports   26.21
# 9    Tennis Racket   Sports   36.07

# %%
complaints_journey = pd.merge(key_complaints, journey_df1)
complaints_journey
# Out:
#     ProductID                                         ReviewText  Rating  \
# 0          13            Average  experience,  nothing  special.     3.0
# 1          13            Average  experience,  nothing  special.     3.0
# 2          13            Average  experience,  nothing  special.     3.0
# 3          17            Average  experience,  nothing  special.     2.5
# 4          17            Average  experience,  nothing  special.     2.5
# 5          17            Average  experience,  nothing  special.     2.5
# 6          17            Average  experience,  nothing  special.     2.5
# 7          17            Average  experience,  nothing  special.     2.5
# 8          16            Average  experience,  nothing  special.     2.0
# 9          16            Average  experience,  nothing  special.     2.0
# 10         16            Average  experience,  nothing  special.     2.0
# 11         16            Average  experience,  nothing  special.     2.0
# 12         16            Average  experience,  nothing  special.     2.0
# 13         10              Disappointed  with  the  performance.     2.0
# 14         10              Disappointed  with  the  performance.     2.0
# 15         10              Disappointed  with  the  performance.     2.0
# 16         10              Disappointed  with  the  performance.     2.0
# 17         10              Disappointed  with  the  performance.     2.0
# 18         10              Disappointed  with  the  performance.     2.0
# 19         10              Disappointed  with  the  performance.     2.0
# 20          2       Product  did    not  meet  my  expectations.     2.0
# 21          2       Product  did    not  meet  my  expectations.     2.0
# 22          2       Product  did    not  meet  my  expectations.     2.0
# 23          2       Product  did    not  meet  my  expectations.     2.0
# 24          2       Product  did    not  meet  my  expectations.     2.0
# 25          2       Product  did    not  meet  my  expectations.     2.0
# 26          7  The  product    is  okay,  but  the  instructi...     2.0
# 27         15                     The  product  arrived    late.     2.0
# 28         15                     The  product  arrived    late.     2.0
# 29         15                     The  product  arrived    late.     2.0
# 30         15                     The  product  arrived    late.     2.0
# 31         15                     The  product  arrived    late.     2.0
# 32         15                     The  product  arrived    late.     2.0
# 33          3                            Not  worth  the  money.     1.0
# 34          3                            Not  worth  the  money.     1.0
# 35          4   The  product  stopped  working  after  a  month.     1.0
# 36          4   The  product  stopped  working  after  a  month.     1.0
# 37          4   The  product  stopped  working  after  a  month.     1.0
# 38          4   The  product  stopped  working  after  a  month.     1.0
# 39          4   The  product  stopped  working  after  a  month.     1.0
# 40          6   I  had  a  bad  experience  with  this  product.     1.0
# 41          6   I  had  a  bad  experience  with  this  product.     1.0
# 42          6   I  had  a  bad  experience  with  this  product.     1.0
# 43          6   I  had  a  bad  experience  with  this  product.     1.0
#
#     JourneyID  CustomerID   VisitDate        Stage    Action    Duration
# 0          14          14  2025-11-01  ProductPage      View   13.000000
# 1          48          52  2025-02-01     Homepage      View  241.000000
# 2          74          81  2024-09-26     Homepage     Click  291.000000
# 3          29          12  2025-06-01     Homepage      View  205.000000
# 4          37          38  2024-06-18     Checkout  Drop-off  166.534884
# 5          70          75  2023-07-07     Homepage      View  297.000000
# 6          76          42  2025-05-29     Checkout  Purchase  261.000000
# 7          78          46  2025-06-15     Checkout  Purchase  122.000000
# 8          10          44  2025-04-23  ProductPage      View   30.000000
# 9          16          14  2024-07-17     Homepage      View   46.000000
# 10         68          45  2023-04-29  ProductPage     Click  250.000000
# 11         73          20  2024-09-17     Homepage      View   17.000000
# 12         99          58  2024-07-06     Checkout  Purchase   87.000000
# 13          5          91  2023-02-11     Homepage     Click  156.000000
# 14          8          99  2025-07-03  ProductPage      View  287.000000
# 15         42          95  2025-01-28     Homepage      View  172.000000
# 16         65          54  2023-12-23     Homepage      View  101.000000
# 17         79          75  2023-11-13     Homepage      View  244.000000
# 18         91          99  2023-12-07     Homepage     Click  244.000000
# 19        100          92  2024-04-06  ProductPage      View  237.000000
# 20         17          67  2025-12-11     Homepage      View  185.000000
# 21         30          48  2023-05-03  ProductPage      View  242.000000
# 22         36          17  2023-11-20     Checkout  Purchase  137.000000
# 23         66          52  2023-11-16     homepage     Click  242.000000
# 24         82          64  2025-06-07     Homepage     Click  261.000000
# 25         87           2  2023-09-25     Homepage      View  277.000000
# 26         55           1  2024-03-17     Checkout  Drop-off  166.534884
# 27         18          70  2025-10-13     Homepage      View  191.000000
# 28         34          55  2023-10-26     Homepage      View  233.000000
# 29         63          51  2025-05-22     Homepage      View  139.000000
# 30         72          47  2023-08-23     Homepage     Click   34.000000
# 31         81          89  2025-10-27     Checkout  Purchase  246.000000
# 32         84          79  2025-03-09     Checkout  Purchase   48.000000
# 33         44          29  2024-02-29     Homepage      View  193.000000
# 34         86          83  2023-09-06     Homepage      View   79.000000
# 35          7          80  2023-08-25     Homepage      View  298.000000
# 36          9          31  2025-06-13  ProductPage      View  278.000000
# 37         53          24  2024-04-05     Homepage      View  182.000000
# 38         77          36  2023-06-02     Homepage     Click  100.000000
# 39         85          56  2023-05-26     Homepage     Click  166.000000
# 40         24          77  2025-06-25     Checkout  Drop-off  166.534884
# 41         45          94  2023-06-07  productpage      View  118.000000
# 42         60          19  2025-06-17  ProductPage      View  190.000000
# 43         80          64  2025-04-06     Homepage     Click  161.000000

# %%
# Pattern between negative review and product performance
performance = complaints_journey.groupby(["Rating","ProductID","ReviewText","Action"])["Action"].count()
performance
# Out:
# Rating  ProductID  ReviewText                                                         Action
# 1.0     3          Not  worth  the  money.                                            View        2
#         4          The  product  stopped  working  after  a  month.                   Click       2
#                                                                                       View        3
#         6          I  had  a  bad  experience  with  this  product.                   Click       1
#                                                                                       Drop-off    1
#                                                                                       View        2
# 2.0     2          Product  did    not  meet  my  expectations.                       Click       2
#                                                                                       Purchase    1
#                                                                                       View        3
#         7          The  product    is  okay,  but  the  instructions  were  unclear.  Drop-off    1
#         10         Disappointed  with  the  performance.                              Click       2
#                                                                                       View        5
#         15         The  product  arrived    late.                                     Click       1
#                                                                                       Purchase    2
#                                                                                       View        3
#         16         Average  experience,  nothing  special.                            Click       1
#                                                                                       Purchase    1
#                                                                                       View        3
# 2.5     17         Average  experience,  nothing  special.                            Drop-off    1
#                                                                                       Purchase    2
#                                                                                       View        2
# 3.0     13         Average  experience,  nothing  special.                            Click       1
#                                                                                       View        2
# Name: Action, dtype: int64

# %%
engagement_df['ContentType'] = engagement_df['ContentType'].str.lower()
journey_df1['Stage'] = journey_df1['Stage'].str.lower()
journey_df1['Action'] = journey_df1['Action'].str.lower()

# %%
# common action leading to successful conversion

successful_purchases = journey_df1[journey_df1['Action'] == 'purchase']
successful_purchases
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate     Stage    Action  Duration
# 35         36          17          2  2023-11-20  checkout  purchase     137.0
# 75         76          42         17  2025-05-29  checkout  purchase     261.0
# 77         78          46         17  2025-06-15  checkout  purchase     122.0
# 80         81          89         15  2025-10-27  checkout  purchase     246.0
# 83         84          79         15  2025-03-09  checkout  purchase      48.0
# 98         99          58         16  2024-07-06  checkout  purchase      87.0

# %%
merged_data = pd.merge(successful_purchases, engagement_df, on='ProductID')
merged_data
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate     Stage    Action  \
# 0          36          17          2  2023-11-20  checkout  purchase
# 1          36          17          2  2023-11-20  checkout  purchase
# 2          36          17          2  2023-11-20  checkout  purchase
# 3          36          17          2  2023-11-20  checkout  purchase
# 4          36          17          2  2023-11-20  checkout  purchase
# 5          36          17          2  2023-11-20  checkout  purchase
# 6          76          42         17  2025-05-29  checkout  purchase
# 7          76          42         17  2025-05-29  checkout  purchase
# 8          76          42         17  2025-05-29  checkout  purchase
# 9          76          42         17  2025-05-29  checkout  purchase
# 10         76          42         17  2025-05-29  checkout  purchase
# 11         78          46         17  2025-06-15  checkout  purchase
# 12         78          46         17  2025-06-15  checkout  purchase
# 13         78          46         17  2025-06-15  checkout  purchase
# 14         78          46         17  2025-06-15  checkout  purchase
# 15         78          46         17  2025-06-15  checkout  purchase
# 16         81          89         15  2025-10-27  checkout  purchase
# 17         81          89         15  2025-10-27  checkout  purchase
# 18         81          89         15  2025-10-27  checkout  purchase
# 19         81          89         15  2025-10-27  checkout  purchase
# 20         81          89         15  2025-10-27  checkout  purchase
# 21         81          89         15  2025-10-27  checkout  purchase
# 22         81          89         15  2025-10-27  checkout  purchase
# 23         84          79         15  2025-03-09  checkout  purchase
# 24         84          79         15  2025-03-09  checkout  purchase
# 25         84          79         15  2025-03-09  checkout  purchase
# 26         84          79         15  2025-03-09  checkout  purchase
# 27         84          79         15  2025-03-09  checkout  purchase
# 28         84          79         15  2025-03-09  checkout  purchase
# 29         84          79         15  2025-03-09  checkout  purchase
# 30         99          58         16  2024-07-06  checkout  purchase
# 31         99          58         16  2024-07-06  checkout  purchase
# 32         99          58         16  2024-07-06  checkout  purchase
# 33         99          58         16  2024-07-06  checkout  purchase
# 34         99          58         16  2024-07-06  checkout  purchase
# 35         99          58         16  2024-07-06  checkout  purchase
# 36         99          58         16  2024-07-06  checkout  purchase
# 37         99          58         16  2024-07-06  checkout  purchase
#
#     Duration  EngagementID  ContentID  ContentType  Likes EngagementDate  \
# 0      137.0             7         33  socialmedia      1     2025-10-01
# 1      137.0            14          2  socialmedia    317     2023-08-26
# 2      137.0            78         44  socialmedia      2     2025-06-07
# 3      137.0            81         30   newsletter     11     2024-06-30
# 4      137.0            83         48        video     14     2025-02-20
# 5      137.0            87          8         blog    111     2024-07-27
# 6      261.0            30         29   newsletter     14     2024-09-10
# 7      261.0            51         44   newsletter     44     2025-02-25
# 8      261.0            54         40         blog      0     2025-09-22
# 9      261.0            93         23  socialmedia    147     2023-02-19
# 10     261.0            94         33        video    389     2023-02-18
# 11     122.0            30         29   newsletter     14     2024-09-10
# 12     122.0            51         44   newsletter     44     2025-02-25
# 13     122.0            54         40         blog      0     2025-09-22
# 14     122.0            93         23  socialmedia    147     2023-02-19
# 15     122.0            94         33        video    389     2023-02-18
# 16     246.0             5         16   newsletter    306     2024-02-21
# 17     246.0            10          4         blog     25     2023-12-03
# 18     246.0            35          2        video      1     2025-07-26
# 19     246.0            38         30   newsletter    449     2023-01-02
# 20     246.0            52         41         blog      3     2025-04-22
# 21     246.0            53         41        video      2     2024-09-20
# 22     246.0            64         49        video      0     2025-12-03
# 23      48.0             5         16   newsletter    306     2024-02-21
# 24      48.0            10          4         blog     25     2023-12-03
# 25      48.0            35          2        video      1     2025-07-26
# 26      48.0            38         30   newsletter    449     2023-01-02
# 27      48.0            52         41         blog      3     2025-04-22
# 28      48.0            53         41        video      2     2024-09-20
# 29      48.0            64         49        video      0     2025-12-03
# 30      87.0             9         48         blog    123     2024-03-19
# 31      87.0            16          2  socialmedia    276     2023-07-06
# 32      87.0            22         11        video    357     2024-04-04
# 33      87.0            24         38   newsletter     65     2024-05-20
# 34      87.0            28         29  socialmedia      7     2023-12-22
# 35      87.0            32         37         blog      0     2025-11-04
# 36      87.0            63         31   newsletter      6     2025-03-28
# 37      87.0            79         36        video    397     2023-04-26
#
#     CampaignID ViewsClicksCombined
# 0           12              750-34
# 1           16           6837-2251
# 2           17              713-44
# 3           11             581-117
# 4            9            1933-158
# 5            2            3142-602
# 6           20            1010-196
# 7            6            2725-358
# 8           13              706-34
# 9            1           2989-1283
# 10          15            2595-933
# 11          20            1010-196
# 12           6            2725-358
# 13          13              706-34
# 14           1           2989-1283
# 15          15            2595-933
# 16           6           5116-1524
# 17          15            4279-297
# 18          13              704-17
# 19          16            2674-956
# 20           3             1617-70
# 21          16              599-39
# 22           1               111-3
# 23           6           5116-1524
# 24          15            4279-297
# 25          13              704-17
# 26          16            2674-956
# 27           3             1617-70
# 28          16              599-39
# 29           1               111-3
# 30          13           5571-1527
# 31          17           5980-1227
# 32          12           5543-1288
# 33           8            3651-377
# 34           2              165-48
# 35          19               441-9
# 36          16             1473-97
# 37           9           3632-1500

# %%
purchase_by_content = merged_data['ContentType'].value_counts().reset_index()
purchase_by_content
# Out:
#    ContentType  PurchaseCount
# 0   newsletter             11
# 1        video             11
# 2         blog              9
# 3  socialmedia              7

# %%
total_engagements = engagement_df['ContentType'].value_counts().reset_index()
total_engagements
# Out:
#    ContentType  count
# 0        video     31
# 1         blog     28
# 2  socialmedia     24
# 3   newsletter     17

# %%
conversion_rates = pd.merge(purchase_by_content, total_engagements, on='ContentType', how='left')
conversion_rates['ConversionRate'] = (conversion_rates['PurchaseCount'] / conversion_rates['count']) * 100
conversion_rates['ConversionRate']
# Out:
# 0    64.705882
# 1    35.483871
# 2    32.142857
# 3    29.166667
# Name: ConversionRate, dtype: float64

# %%
print("\nConversion Rates by Content Type:")
print(conversion_rates.sort_values('ConversionRate', ascending=False))
# Out:
# Conversion Rates by Content Type:
#    ContentType  PurchaseCount  count  ConversionRate
# 0   newsletter             11     17       64.705882
# 1        video             11     31       35.483871
# 2         blog              9     28       32.142857
# 3  socialmedia              7     24       29.166667

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Plot 1: Successful purchases by content type
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 2)
plt.bar(purchase_by_content['ContentType'], purchase_by_content['PurchaseCount'], color='skyblue')
plt.title('Successful Purchases by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Number of Purchases')
# Out:
# Text(0, 0.5, 'Number of Purchases')

# %%
# Plot 2: Conversion rates by content type
plt.subplot(1, 2, 2)
plt.bar(conversion_rates['ContentType'], conversion_rates['ConversionRate'], color='lightgreen')
plt.title('Conversion Rates by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Conversion Rate (%)')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
